# %% [markdown]
# <h1> Analysis on Credit Card Default </h1>
# <h2> About Data </h2>
#
# The Default of Credit Card Clients Dataset is sourced from the UCI Machine Learning Repository. It provides information on default payments, demographic factors, credit data, payment history, and billing statements of credit card clients in Taiwan from April 2005 to September 2005.
#
# **Dataset Details:**
#
# - Number of Instances (Rows): 30,000
# - Number of Variables (Columns): 25
#
# **Target Variable:**
#
# The target variable (label) is the 'default payment next month' column, which indicates whether a client will default on their payment next month. It is encoded as follows:
# - 1: Default payment next month (Yes)
# - 0: No default payment next month (No)
#
# **Features (Independent Variables):**
#
# The remaining columns in the dataset are features, which include:
#
# - `ID`: ID of each client
# - `LIMIT_BAL`: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
# - `SEX`: Gender (1 = male, 2 = female)
# - `EDUCATION`: Education level (1 = graduate school, 2 = university, 3 = high school, 4 = others)
# - `MARRIAGE`: Marital status (1 = married, 2 = single, 3 = others)
# - `AGE`: Age in years
# - `PAY_0`, `PAY_2` - `PAY_6`: Repayment status in September 2005, August 2005, ..., April 2005 (scale: -1 = pay duly, 1 = payment delay for one month, 2 = payment delay for two months, ..., 8 = payment delay for eight months, 9 = payment delay for nine months and above)
# - `BILL_AMT1` - `BILL_AMT6`: Amount of bill statement in September 2005, August 2005, ..., April 2005 (NT dollar)
# - `PAY_AMT1` - `PAY_AMT6`: Amount of previous payment in September 2005, August 2005, ..., April 2005 (NT dollar)

# %% [markdown]
# <h2> Data Retrieval and Preprocessing </h2>

# %%
# import data
import pandas as pd
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls'
data = pd.read_excel(url,header=1)
cc = data.copy()
cc = cc.drop(['ID'],axis=1)
cc.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 24 columns]

# %%
y = cc['default payment next month']
X = cc.drop(['default payment next month'], axis=1)

# %%
#pertubate data 

import numpy as np

np.random.seed(1992)
noise = np.random.normal(0, 1, X.shape)
X_perturbed = X + noise
X_perturbed.head()
# Out:
#        LIMIT_BAL       SEX  EDUCATION  MARRIAGE        AGE     PAY_0  \
# 0   19999.764837  3.078820   1.573994  1.226979  25.355065  3.091244
# 1  120000.539409  2.036679   2.530178  1.737043  26.917942 -0.818469
# 2   89998.706197  1.707039   0.245267  2.764420  31.704897  2.460652
# 3   49999.503182  1.000606   1.739712 -1.136602  36.080728  0.992506
# 4   50000.413875  1.429502   2.389036  0.437236  56.301169  1.248528
#
#       PAY_2     PAY_3     PAY_4     PAY_5  ...     BILL_AMT3     BILL_AMT4  \
# 0  2.330408  1.190902 -1.223310 -1.551322  ...    688.277507     -1.901867
# 1  1.841601 -1.774385 -0.945756 -0.559102  ...   2681.371854   3272.375855
# 2  0.009003  0.896342  1.473940  1.171253  ...  13559.301246  14332.907388
# 3  0.374069 -0.671272 -2.018546  0.706513  ...  49291.638804  28315.042186
# 4  0.461247 -0.332519 -0.356791 -0.908324  ...  35832.844840  20938.130623
#
#       BILL_AMT5     BILL_AMT6     PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# 0     -0.871000     -0.327478     2.880395    689.593235     -0.430066
# 1   3455.239218   3261.197808    -1.241448    999.868616   1000.982549
# 2  14948.052325  15549.054446  1517.633396   1499.626756   1000.451516
# 3  28958.406604  29548.149135  1998.313568   2020.431728   1199.497850
# 4  19144.698725  19131.440467  1999.179897  36681.335817  10000.183982
#
#       PAY_AMT4     PAY_AMT5     PAY_AMT6
# 0    -0.203135    -0.241548     0.228578
# 1   999.984840    -1.180752  2001.259424
# 2  1001.430434   998.972048  4999.544676
# 3  1100.399551  1069.858761   998.437948
# 4  9000.314732   690.035701   679.152289
#
# [5 rows x 23 columns]

# %% [markdown]
# <h2> PCA </h2>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_p_std = scaler.fit_transform(X_perturbed)

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit_transform(X_p_std)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_.cumsum(),lw=2, color='blue')
plt.grid(True, linestyle='--', alpha=0.6)
plt.axhline(y=0.8, color='grey', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.show();

""""
Comment on graph:

The graph showing cumulative explained variance by principal components is rather smooth until around 19 principal components which is starts to plateau.
Since graph is smooth, it is not straightforward to select the number of principal components to use to maximise variance explained while using less principal components.
Here, using a percentage to guide our selection would be more helpful than through a visual selection.

"""
# Out:
# '"\nComment on graph:\n\nThe graph showing cumulative explained variance by principal components is rather smooth until around 19 principal components which is starts to plateau.\nSince graph is smooth, it is not straightforward to select the number of principal components to use to maximise variance explained while using less principal components.\nHere, using a percentage to guide our selection would be more helpful than through a visual selection.\n\n'

# %%
count = 0
for i in pca.explained_variance_ratio_.cumsum():
    count +=1
    if i >= 0.8:
        print(f'Number of principal components to keep: {count}') 
        break
# Out:
# Number of principal components to keep: 12

# %%
pca = PCA(n_components=12)
X_pca_12 = pca.fit_transform(X_p_std)

# %% [markdown]
# <h2> Neural Network Classfication without PCA </h2>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_perturbed, y, test_size=0.30, random_state=1992)

from tensorflow import keras
from keras import layers
from tensorflow.keras.callbacks import EarlyStopping


model = keras.Sequential([
    layers.Dense(256, activation='relu',input_shape=[X_train.shape[1]]),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1,activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, callbacks=[early_stop], verbose=1)
# Out:
# 2023-08-14 15:53:00.171137: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 329/329 [==============================] - 2s 3ms/step - loss: 808.7281 - accuracy: 0.6737 - val_loss: 1.5207 - val_accuracy: 0.7540
# Epoch 2/100
# 329/329 [==============================] - 1s 2ms/step - loss: 15.3563 - accuracy: 0.6743 - val_loss: 0.7162 - val_accuracy: 0.5738
# Epoch 3/100
# 329/329 [==============================] - 1s 2ms/step - loss: 4.2340 - accuracy: 0.7476 - val_loss: 0.5988 - val_accuracy: 0.7823
# Epoch 4/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.6671 - accuracy: 0.7615 - val_loss: 0.5560 - val_accuracy: 0.7823
# Epoch 5/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.6130 - accuracy: 0.7703 - val_loss: 0.5367 - val_accuracy: 0.7823
# Epoch 6/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4159 - accuracy: 0.7737 - val_loss: 0.5291 - val_accuracy: 0.7823
# Epoch 7/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4013 - accuracy: 0.7743 - val_loss: 0.5260 - val_accuracy: 0.7823
# Epoch 8/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.9464 - accuracy: 0.7754 - val_loss: 0.5248 - val_accuracy: 0.7823
# Epoch 9/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7643 - accuracy: 0.7758 - val_loss: 0.5243 - val_accuracy: 0.7823
# Epoch 10/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6867 - accuracy: 0.7764 - val_loss: 0.5241 - val_accuracy: 0.7823
# Epoch 11/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.3826 - accuracy: 0.7763 - val_loss: 0.5241 - val_accuracy: 0.7823
# Epoch 12/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7910 - accuracy: 0.7768 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 13/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6457 - accuracy: 0.7766 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 14/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7976 - accuracy: 0.7768 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 15/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5942 - accuracy: 0.7768 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 16/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5641 - accuracy: 0.7770 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 17/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6993 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 18/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5783 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 19/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5860 - accuracy: 0.7770 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 20/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6109 - accuracy: 0.7770 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 21/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 22/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5303 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 23/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 24/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7772 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 25/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5302 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 26/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7774 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 27/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5304 - accuracy: 0.7772 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 28/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5303 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 29/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 30/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5306 - accuracy: 0.7772 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 31/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 32/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 32: early stopping

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epochs')
plt.legend()
plt.show();

# %%
scores = model.evaluate(X_test, y_test)
print(f'{model.metrics_names[1]}: {scores[1]*100}')
# Out:
# 282/282 [==============================] - 0s 947us/step - loss: 0.5240 - accuracy: 0.7823
# accuracy: 78.23333144187927

# %% [markdown]
# <h2> Neural Network Classfication after PCA </h2>

# %%
# Retaining 12 principal components as selected earlier
pca = PCA(n_components=12)
pca.fit_transform(X_p_std)
P = pca.components_
X_pca = np.dot(X_perturbed, P.T)

# %%
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y, test_size=0.30, random_state=1992)


model = keras.Sequential([
    layers.Dense(256, activation='relu',input_shape=[X_train_pca.shape[1]]),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1,activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
history = model.fit(X_train_pca, y_train_pca, validation_data=(X_test_pca, y_test_pca), epochs=100, batch_size=64, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/100
# 329/329 [==============================] - 2s 2ms/step - loss: 799.8810 - accuracy: 0.6784 - val_loss: 0.8676 - val_accuracy: 0.7483
# Epoch 2/100
# 329/329 [==============================] - 1s 2ms/step - loss: 13.0903 - accuracy: 0.6657 - val_loss: 0.6659 - val_accuracy: 0.7823
# Epoch 3/100
# 329/329 [==============================] - 1s 2ms/step - loss: 3.7716 - accuracy: 0.7511 - val_loss: 0.5875 - val_accuracy: 0.7823
# Epoch 4/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.8687 - accuracy: 0.7644 - val_loss: 0.5509 - val_accuracy: 0.7823
# Epoch 5/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.5927 - accuracy: 0.7698 - val_loss: 0.5354 - val_accuracy: 0.7823
# Epoch 6/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.3950 - accuracy: 0.7728 - val_loss: 0.5287 - val_accuracy: 0.7823
# Epoch 7/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0320 - accuracy: 0.7735 - val_loss: 0.5468 - val_accuracy: 0.7823
# Epoch 8/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.9569 - accuracy: 0.7750 - val_loss: 0.5246 - val_accuracy: 0.7823
# Epoch 9/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.8587 - accuracy: 0.7753 - val_loss: 0.5242 - val_accuracy: 0.7823
# Epoch 10/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7379 - accuracy: 0.7762 - val_loss: 0.5241 - val_accuracy: 0.7823
# Epoch 11/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6448 - accuracy: 0.7768 - val_loss: 0.5241 - val_accuracy: 0.7823
# Epoch 12/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7126 - accuracy: 0.7768 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 13/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6542 - accuracy: 0.7766 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 14/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.5757 - accuracy: 0.7771 - val_loss: 0.8321 - val_accuracy: 0.7823
# Epoch 15/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.9178 - accuracy: 0.7769 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 16/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.8423 - accuracy: 0.7768 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 17/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6022 - accuracy: 0.7774 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 18/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5703 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 19/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5890 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 20/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5914 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 21/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7858 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 22/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7772 - val_loss: 0.5241 - val_accuracy: 0.7823
# Epoch 23/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5433 - accuracy: 0.7773 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 24/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6365 - accuracy: 0.7772 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 25/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7674 - accuracy: 0.7771 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 26/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7662 - accuracy: 0.7771 - val_loss: 0.5448 - val_accuracy: 0.7823
# Epoch 27/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7773 - val_loss: 0.5450 - val_accuracy: 0.7823
# Epoch 28/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5317 - accuracy: 0.7773 - val_loss: 0.5450 - val_accuracy: 0.7823
# Epoch 29/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7772 - val_loss: 0.5628 - val_accuracy: 0.7823
# Epoch 30/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6544 - accuracy: 0.7772 - val_loss: 0.5240 - val_accuracy: 0.7823
# Epoch 30: early stopping

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epochs')
plt.legend()
plt.show();

# %%
scores = model.evaluate(X_test_pca, y_test_pca)
print(f'{model.metrics_names[1]}: {scores[1]*100}')
# Out:
# 282/282 [==============================] - 0s 1ms/step - loss: 0.5240 - accuracy: 0.7823
# accuracy: 78.23333144187927

# %% [markdown]
# <h2> Comments </h2>
# It should also be noted that as it more uncommon for default to happen in real life, our dataset used could be slightly unbalanced.
# Only around 22% of our data is default data and hence, our predictions of credit card default might be biased to the proportion of default in the training dataset.
# We can consider using weights when training our model or doing resampling to make our predictions more robust.
#
# In the problems, we used the metric of accuracy to determine our results but in the real life scenario of credit card default cases, banks might be more interested
# in other metrics as they are more interested in having less false negatives,i.e. reducing type 2 error.
# Using accuracy could also explain why validation accuracy is higher than training accuracy which is not usual.
# Our model might be predicting less defaults due to imbalanced dataset which will give higher accuracy scores.

# %%
non_default = len(data[data['default payment next month']==0])
default = len(data[data['default payment next month']==1])
ratio = float(default/(non_default+default))
print('Default Ratio :',ratio)
# Out:
# Default Ratio : 0.2212

# %% [markdown]
# It should also be noted that as it more uncommon for default to happen in real life, our dataset used could be slightly unbalanced.
# Only around 22% of our data is default data and hence, our predictions of credit card default might be biased to the proportion of default in the training dataset.
# We can consider using weights when training our model or doing resampling to make our predictions more robust.
#
# In the problems, we used the metric of accuracy to determine our results but in the real life scenario of credit card default cases, banks might be more interested
# in other metrics as they are more interested in having less false negatives,i.e. reducing type 2 error.
# Using accuracy could also explain why validation accuracy is higher than training accuracy which is not usual.
# Our model might be predicting less defaults due to imbalanced dataset which will give higher accuracy scores.

# %%
# Exploring without dropout layers

X_train, X_test, y_train, y_test = train_test_split(X_perturbed, y, test_size=0.30, random_state=1992)

from tensorflow import keras
from keras import layers
from tensorflow.keras.callbacks import EarlyStopping


model = keras.Sequential([
    layers.Dense(128, activation='relu',input_shape=[X_train.shape[1]]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1,activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/100
# 329/329 [==============================] - 1s 2ms/step - loss: 438.1126 - accuracy: 0.6920 - val_loss: 122.3340 - val_accuracy: 0.7156
# Epoch 2/100
# 329/329 [==============================] - 0s 1ms/step - loss: 269.0228 - accuracy: 0.6927 - val_loss: 2030.1584 - val_accuracy: 0.2323
# Epoch 3/100
# 329/329 [==============================] - 0s 1ms/step - loss: 293.7437 - accuracy: 0.6949 - val_loss: 854.9665 - val_accuracy: 0.2669
# Epoch 4/100
# 329/329 [==============================] - 0s 1ms/step - loss: 185.6978 - accuracy: 0.6958 - val_loss: 346.8346 - val_accuracy: 0.7809
# Epoch 5/100
# 329/329 [==============================] - 0s 1ms/step - loss: 154.6208 - accuracy: 0.6964 - val_loss: 137.6388 - val_accuracy: 0.7067
# Epoch 6/100
# 329/329 [==============================] - 0s 1ms/step - loss: 142.3568 - accuracy: 0.6992 - val_loss: 64.2147 - val_accuracy: 0.7576
# Epoch 7/100
# 329/329 [==============================] - 0s 2ms/step - loss: 113.5916 - accuracy: 0.6984 - val_loss: 305.8217 - val_accuracy: 0.7797
# Epoch 8/100
# 329/329 [==============================] - 1s 2ms/step - loss: 109.9966 - accuracy: 0.7004 - val_loss: 202.8581 - val_accuracy: 0.4257
# Epoch 9/100
# 329/329 [==============================] - 0s 1ms/step - loss: 95.4949 - accuracy: 0.6944 - val_loss: 161.0027 - val_accuracy: 0.7776
# Epoch 10/100
# 329/329 [==============================] - 0s 1ms/step - loss: 118.9007 - accuracy: 0.6952 - val_loss: 211.8260 - val_accuracy: 0.4341
# Epoch 11/100
# 329/329 [==============================] - 1s 2ms/step - loss: 96.1362 - accuracy: 0.6982 - val_loss: 63.3520 - val_accuracy: 0.6921
# Epoch 12/100
# 329/329 [==============================] - 0s 1ms/step - loss: 82.0861 - accuracy: 0.6979 - val_loss: 93.1317 - val_accuracy: 0.7794
# Epoch 13/100
# 329/329 [==============================] - 0s 1ms/step - loss: 82.9365 - accuracy: 0.6969 - val_loss: 33.8764 - val_accuracy: 0.7618
# Epoch 14/100
# 329/329 [==============================] - 1s 2ms/step - loss: 61.2432 - accuracy: 0.6978 - val_loss: 44.7295 - val_accuracy: 0.6938
# Epoch 15/100
# 329/329 [==============================] - 0s 1ms/step - loss: 64.2870 - accuracy: 0.6949 - val_loss: 67.6467 - val_accuracy: 0.5783
# Epoch 16/100
# 329/329 [==============================] - 0s 1ms/step - loss: 45.6687 - accuracy: 0.7008 - val_loss: 40.0726 - val_accuracy: 0.7662
# Epoch 17/100
# 329/329 [==============================] - 0s 1ms/step - loss: 45.1894 - accuracy: 0.7037 - val_loss: 24.5070 - val_accuracy: 0.6637
# Epoch 18/100
# 329/329 [==============================] - 0s 1ms/step - loss: 51.0553 - accuracy: 0.6986 - val_loss: 26.9941 - val_accuracy: 0.7710
# Epoch 19/100
# 329/329 [==============================] - 1s 2ms/step - loss: 41.4666 - accuracy: 0.7021 - val_loss: 27.8130 - val_accuracy: 0.7536
# Epoch 20/100
# 329/329 [==============================] - 0s 1ms/step - loss: 32.0552 - accuracy: 0.6985 - val_loss: 40.4747 - val_accuracy: 0.7743
# Epoch 21/100
# 329/329 [==============================] - 0s 1ms/step - loss: 30.7851 - accuracy: 0.7038 - val_loss: 41.5144 - val_accuracy: 0.7766
# Epoch 22/100
# 329/329 [==============================] - 0s 1ms/step - loss: 36.1242 - accuracy: 0.6984 - val_loss: 40.3826 - val_accuracy: 0.7626
# Epoch 23/100
# 329/329 [==============================] - 0s 1ms/step - loss: 27.3309 - accuracy: 0.6991 - val_loss: 55.5435 - val_accuracy: 0.7780
# Epoch 24/100
# 329/329 [==============================] - 0s 1ms/step - loss: 25.9789 - accuracy: 0.7010 - val_loss: 13.2836 - val_accuracy: 0.7506
# Epoch 25/100
# 329/329 [==============================] - 0s 1ms/step - loss: 24.8496 - accuracy: 0.7013 - val_loss: 39.1953 - val_accuracy: 0.7812
# Epoch 26/100
# 329/329 [==============================] - 0s 1ms/step - loss: 17.7284 - accuracy: 0.6986 - val_loss: 12.4152 - val_accuracy: 0.7643
# Epoch 27/100
# 329/329 [==============================] - 0s 1ms/step - loss: 15.4296 - accuracy: 0.6970 - val_loss: 17.3868 - val_accuracy: 0.4742
# Epoch 28/100
# 329/329 [==============================] - 0s 1ms/step - loss: 15.7512 - accuracy: 0.6990 - val_loss: 11.3921 - val_accuracy: 0.7771
# Epoch 29/100
# 329/329 [==============================] - 1s 2ms/step - loss: 12.8543 - accuracy: 0.6966 - val_loss: 12.4937 - val_accuracy: 0.5887
# Epoch 30/100
# 329/329 [==============================] - 0s 1ms/step - loss: 13.0415 - accuracy: 0.6969 - val_loss: 17.0972 - val_accuracy: 0.7610
# Epoch 31/100
# 329/329 [==============================] - 0s 1ms/step - loss: 12.1763 - accuracy: 0.6951 - val_loss: 11.0003 - val_accuracy: 0.7679
# Epoch 32/100
# 329/329 [==============================] - 0s 1ms/step - loss: 9.4785 - accuracy: 0.6985 - val_loss: 11.9635 - val_accuracy: 0.4603
# Epoch 33/100
# 329/329 [==============================] - 0s 1ms/step - loss: 6.6023 - accuracy: 0.6953 - val_loss: 8.8390 - val_accuracy: 0.7617
# Epoch 34/100
# 329/329 [==============================] - 0s 1ms/step - loss: 6.6197 - accuracy: 0.7001 - val_loss: 10.8512 - val_accuracy: 0.4769
# Epoch 35/100
# 329/329 [==============================] - 0s 2ms/step - loss: 7.7580 - accuracy: 0.6911 - val_loss: 17.2699 - val_accuracy: 0.7796
# Epoch 36/100
# 329/329 [==============================] - 0s 2ms/step - loss: 6.1433 - accuracy: 0.6923 - val_loss: 6.8894 - val_accuracy: 0.5050
# Epoch 37/100
# 329/329 [==============================] - 0s 2ms/step - loss: 4.6846 - accuracy: 0.6868 - val_loss: 5.0840 - val_accuracy: 0.5990
# Epoch 38/100
# 329/329 [==============================] - 1s 2ms/step - loss: 3.5578 - accuracy: 0.6832 - val_loss: 2.2994 - val_accuracy: 0.6331
# Epoch 39/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.9615 - accuracy: 0.6826 - val_loss: 4.4307 - val_accuracy: 0.5149
# Epoch 40/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.6971 - accuracy: 0.6778 - val_loss: 3.0463 - val_accuracy: 0.7646
# Epoch 41/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.1413 - accuracy: 0.6772 - val_loss: 1.7175 - val_accuracy: 0.6836
# Epoch 42/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4956 - accuracy: 0.6777 - val_loss: 1.8815 - val_accuracy: 0.7260
# Epoch 43/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4552 - accuracy: 0.6408 - val_loss: 1.5193 - val_accuracy: 0.5614
# Epoch 44/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0238 - accuracy: 0.6512 - val_loss: 1.1572 - val_accuracy: 0.6257
# Epoch 45/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.8310 - accuracy: 0.7194 - val_loss: 1.2527 - val_accuracy: 0.7746
# Epoch 46/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7193 - accuracy: 0.7514 - val_loss: 1.1994 - val_accuracy: 0.7774
# Epoch 47/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.7152 - accuracy: 0.7536 - val_loss: 1.0290 - val_accuracy: 0.6813
# Epoch 48/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6708 - accuracy: 0.7670 - val_loss: 0.8951 - val_accuracy: 0.7796
# Epoch 49/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6296 - accuracy: 0.7725 - val_loss: 0.9010 - val_accuracy: 0.7662
# Epoch 50/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5982 - accuracy: 0.7745 - val_loss: 0.9713 - val_accuracy: 0.7811
# Epoch 51/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.9652 - accuracy: 0.7708 - val_loss: 0.8536 - val_accuracy: 0.7813
# Epoch 52/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6150 - accuracy: 0.7752 - val_loss: 0.8291 - val_accuracy: 0.7793
# Epoch 53/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6539 - accuracy: 0.7747 - val_loss: 0.7959 - val_accuracy: 0.7798
# Epoch 54/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5834 - accuracy: 0.7767 - val_loss: 0.8523 - val_accuracy: 0.7757
# Epoch 55/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5612 - accuracy: 0.7767 - val_loss: 0.7790 - val_accuracy: 0.7811
# Epoch 56/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7771 - val_loss: 0.8351 - val_accuracy: 0.7764
# Epoch 57/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7770 - val_loss: 0.7643 - val_accuracy: 0.7810
# Epoch 58/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7776 - val_loss: 0.8371 - val_accuracy: 0.7814
# Epoch 59/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6117 - accuracy: 0.7767 - val_loss: 0.8219 - val_accuracy: 0.7819
# Epoch 60/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7775 - val_loss: 0.7890 - val_accuracy: 0.7820
# Epoch 61/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7777 - val_loss: 0.7897 - val_accuracy: 0.7822
# Epoch 62/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5345 - accuracy: 0.7778 - val_loss: 0.7729 - val_accuracy: 0.7822
# Epoch 63/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5292 - accuracy: 0.7780 - val_loss: 0.7532 - val_accuracy: 0.7823
# Epoch 64/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5288 - accuracy: 0.7779 - val_loss: 0.7495 - val_accuracy: 0.7824
# Epoch 65/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7780 - val_loss: 0.7428 - val_accuracy: 0.7824
# Epoch 66/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5289 - accuracy: 0.7780 - val_loss: 0.7296 - val_accuracy: 0.7822
# Epoch 67/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5797 - accuracy: 0.7778 - val_loss: 0.7860 - val_accuracy: 0.7819
# Epoch 68/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.6718 - accuracy: 0.7776 - val_loss: 0.7362 - val_accuracy: 0.7823
# Epoch 69/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5364 - accuracy: 0.7777 - val_loss: 0.7766 - val_accuracy: 0.7823
# Epoch 70/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5417 - accuracy: 0.7776 - val_loss: 0.7388 - val_accuracy: 0.7822
# Epoch 71/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5308 - accuracy: 0.7778 - val_loss: 0.7376 - val_accuracy: 0.7824
# Epoch 72/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5306 - accuracy: 0.7777 - val_loss: 0.7248 - val_accuracy: 0.7824
# Epoch 73/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7779 - val_loss: 0.7162 - val_accuracy: 0.7824
# Epoch 74/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7779 - val_loss: 0.7083 - val_accuracy: 0.7824
# Epoch 75/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5285 - accuracy: 0.7778 - val_loss: 0.7195 - val_accuracy: 0.7824
# Epoch 76/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.5284 - accuracy: 0.7779 - val_loss: 0.7111 - val_accuracy: 0.7824
# Epoch 77/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5282 - accuracy: 0.7778 - val_loss: 0.7157 - val_accuracy: 0.7824
# Epoch 78/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7779 - val_loss: 0.7053 - val_accuracy: 0.7823
# Epoch 79/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5285 - accuracy: 0.7778 - val_loss: 0.7068 - val_accuracy: 0.7824
# Epoch 80/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7779 - val_loss: 0.7071 - val_accuracy: 0.7824
# Epoch 81/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5283 - accuracy: 0.7779 - val_loss: 0.7051 - val_accuracy: 0.7824
# Epoch 82/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6754 - accuracy: 0.7775 - val_loss: 0.8473 - val_accuracy: 0.7814
# Epoch 83/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4225 - accuracy: 0.7768 - val_loss: 0.7759 - val_accuracy: 0.7822
# Epoch 84/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.6884 - accuracy: 0.7774 - val_loss: 0.8475 - val_accuracy: 0.7822
# Epoch 85/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.8638 - accuracy: 0.7773 - val_loss: 0.8104 - val_accuracy: 0.7822
# Epoch 86/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5642 - accuracy: 0.7776 - val_loss: 1.1851 - val_accuracy: 0.7823
# Epoch 87/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7777 - val_loss: 0.9345 - val_accuracy: 0.7823
# Epoch 88/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7777 - val_loss: 0.9341 - val_accuracy: 0.7823
# Epoch 89/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7777 - val_loss: 0.9342 - val_accuracy: 0.7823
# Epoch 90/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7777 - val_loss: 0.9347 - val_accuracy: 0.7823
# Epoch 91/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.5287 - accuracy: 0.7777 - val_loss: 0.9344 - val_accuracy: 0.7823
# Epoch 91: early stopping

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy by Epochs')
plt.legend()
plt.show();

scores = model.evaluate(X_test, y_test)
print(f'{model.metrics_names[1]}: {scores[1]*100}')
# Out:
# 282/282 [==============================] - 0s 1ms/step - loss: 0.9344 - accuracy: 0.7823
# accuracy: 78.23333144187927

# %% [markdown]
# After removing the dropout layers in the model, we see that accuracy still remains the same. However, validation accuracy is flunctuating a lot.
# This might indicate overfitting since we did not use dropout layers.
# Interesting that validation accuracy is still higher than training accuracy, this might be really because of the unbalanced dataset
# which gives high accuracy if predictions are mostly classfied as not default.
